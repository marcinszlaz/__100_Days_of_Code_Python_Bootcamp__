# %% [markdown]
# # Introduction

# %% [markdown]
# Google Trends gives us an estimate of search volume. Let's explore if search popularity relates to other kinds of data. Perhaps there are patterns in Google's search volume and the price of Bitcoin or a hot stock like Tesla. Perhaps search volume for the term "Unemployment Benefits" can tell us something about the actual unemployment rate?
#
# Data Sources: <br>
# <ul>
# <li> <a href="https://fred.stlouisfed.org/series/UNRATE/">Unemployment Rate from FRED</a></li>
# <li> <a href="https://trends.google.com/trends/explore">Google Trends</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/TSLA/history?p=TSLA">Yahoo Finance for Tesla Stock Price</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD">Yahoo Finance for Bitcoin Stock Price</a> </li>
# </ul>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# # Read the Data
#
# Download and add the .csv files to the same folder as your notebook.

# %%
df_tesla = pd.read_csv('TESLA Search Trend vs Price.csv')

df_btc_search = pd.read_csv('Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv('Daily Bitcoin Price.csv')

df_unemployment = pd.read_csv('UE Benefits Search vs UE Rate 2004-19.csv')

# %%
df_unemployment.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Tesla

# %% [markdown]
# **Challenge**: <br>
# <ul>
# <li>What are the shapes of the dataframes? </li>
# <li>How many rows and columns? </li>
# <li>What are the column names? </li>
# <li>Complete the f-string to show the largest/smallest number in the search data column</li>
# <li>Try the <code>.describe()</code> function to see some useful descriptive statistics</li>
# <li>What is the periodicity of the time series data (daily, weekly, monthly)? </li>
# <li>What does a value of 100 in the Google Trend search popularity actually mean?</li>
# </ul>

# %%
print(f'Largest value for Tesla in Web Search: \n {df_tesla["TSLA_WEB_SEARCH"].max()}')
print(f'Smallest value for Tesla in Web Search: \n {df_tesla["TSLA_WEB_SEARCH"].min()}')
# Out:
# Largest value for Tesla in Web Search:
#  31
# Smallest value for Tesla in Web Search:
#  2

# %% [markdown]
# ### Unemployment Data

# %%
print('Largest value for "Unemployemnt Benefits" '
      f'in Web Search: \n {df_unemployment['UE_BENEFITS_WEB_SEARCH'].max()}')
# Out:
# Largest value for "Unemployemnt Benefits" in Web Search:
#  100

# %% [markdown]
# ### Bitcoin

# %%
df_btc_price.shape
df_btc_price.head()
# Out:
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
df_btc_search.shape
df_btc_search.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
print(f'largest BTC News Search: \n {df_btc_search.BTC_NEWS_SEARCH.max()}')
# Out:
# largest BTC News Search:
#  100

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# **Challenge**: Are there any missing values in any of the dataframes? If so, which row/rows have missing values? How many missing values are there?

# %%
print(f'Missing values for Tesla?: \n{df_tesla.isna().values.any()}')
print(f'Missing values for U/E?: \n {df_unemployment.isna().values.any()}')
print(f'Missing values for BTC Search?: \n {df_btc_search.isna().values.any()}')
# Out:
# Missing values for Tesla?:
# False
# Missing values for U/E?:
#  False
# Missing values for BTC Search?:
#  False

# %%
print(f'Missing values for BTC price?: \n {df_btc_price.isna().values.any()}')
df_btc_price.isna().values.sum()
# Out:
# Missing values for BTC price?:
#  True
# np.int64(2)

# %%
# there was one NaN at 2048 index
print(f'Number of missing values: \n { df_btc_price[df_btc_price.isna().values.any(axis=1)] }')
print(f'Number of missing values: \n { df_btc_price[df_btc_price.apply(axis=1,func=lambda col: col.isna().any(axis=0))] }')
# Out:
# Number of missing values:
#              DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN
# Number of missing values:
#              DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %% [markdown]
# **Challenge**: Remove any missing values that you found.

# %%
df_btc_price.dropna(inplace=True)
print(f'Number of missing values: \n { df_btc_price[df_btc_price.isna().values.any(axis=1)] }')
# Out:
# Number of missing values:
#  Empty DataFrame
# Columns: [DATE, CLOSE, VOLUME]
# Index: []

# %% [markdown]
# ### Convert Strings to DateTime Objects

# %% [markdown]
# **Challenge**: Check the data type of the entries in the DataFrame MONTH or DATE columns. Convert any strings in to Datetime objects. Do this for all 4 DataFrames. Double check if your type conversion was successful.

# %%
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)
df_tesla.dtypes
# Out:
# MONTH              datetime64[us]
# TSLA_WEB_SEARCH             int64
# TSLA_USD_CLOSE            float64
# dtype: object

# %%
df_unemployment_bak = df_unemployment.copy() # .copy() makes full independent copy (not reference xD)
df_unemployment.MONTH = pd.to_datetime(df_unemployment_bak.MONTH)
# df_unemployment_bak.dtypes
df_unemployment.dtypes
# Out:
# MONTH                     datetime64[us]
# UE_BENEFITS_WEB_SEARCH             int64
# UNRATE                           float64
# dtype: object

# %%
df_btc_price.dtypes
df_btc_price.DATE = pd.to_datetime(df_btc_price.DATE)
df_btc_price.dtypes
# Out:
# DATE      datetime64[us]
# CLOSE            float64
# VOLUME           float64
# dtype: object

# %%
df_btc_search.columns
df_btc_search.dtypes
df_btc_search.MONTH = pd.to_datetime(df_btc_search.MONTH)
df_btc_search.MONTH.head()
df_btc_search.dtypes
# Out:
# MONTH              datetime64[us]
# BTC_NEWS_SEARCH             int64
# dtype: object

# %% [markdown]
# ### Converting from Daily to Monthly Data
#
# [Pandas .resample() documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) <br>

# %%
df_btc_search.shape
# Out:
# (73, 2)

# %%
df_btc_price.shape
df_btc_monthly = df_btc_price.resample(rule='ME',on='DATE').last()
# resample converts days to months and other conversion, but you have to do something with rest data
# you need to chose, last value, first value, mean() etc.
df_btc_monthly.shape
# Out:
# (73, 2)

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Notebook Formatting & Style Helpers

# %%
# Create locators for ticks on the time axis
df_tesla.sort_values(by='TSLA_USD_CLOSE', ascending=False).head(10)
df_tesla.sort_values(by='TSLA_WEB_SEARCH', ascending=False).head(10)
# Out:
#          MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 123 2020-09-01               31      407.339996
# 113 2019-11-01               30       65.987999
# 121 2020-07-01               24      286.152008
# 116 2020-02-01               23      133.598007
# 122 2020-08-01               23      498.320007
# 115 2020-01-01               20      130.113998
# 114 2019-12-01               19       83.666000
# 70  2016-04-01               18       48.152000
# 117 2020-03-01               17      104.800003
# 120 2020-06-01               17      215.962006

# %%
# Register date converters to avoid warning messages
df_tesla.sort_values(by='TSLA_WEB_SEARCH', ascending=False)
df_tesla.head(10)
# Out:
#        MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0 2010-06-01                3           4.766
# 1 2010-07-01                3           3.988
# 2 2010-08-01                2           3.896
# 3 2010-09-01                2           4.082
# 4 2010-10-01                2           4.368
# 5 2010-11-01                2           7.066
# 6 2010-12-01                2           5.326
# 7 2011-01-01                3           4.820
# 8 2011-02-01                2           4.778
# 9 2011-03-01                3           5.550

# %% [markdown]
# ### Tesla Stock Price v.s. Search Volume

# %% [markdown]
# **Challenge:** Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes. Label one axis 'TSLA Stock Price' and the other 'Search Trend'.

# %%
df_tesla.head()
ax2 = plt.gca()
ax1 = plt.twinx()
l1, = ax1.plot(df_tesla.MONTH,df_tesla['TSLA_WEB_SEARCH'],label='Search Trend', color = 'blue')
l2, = ax2.plot(df_tesla.MONTH,df_tesla.TSLA_USD_CLOSE,label='TSLA Stock Price', color = 'red')
ax1.set_ylabel('Search Trend', color='blue')
ax2.set_ylabel('TSLA Stock Price',color='red')
plt.title('web search vs stock price')
list = [l1,l2]
labels = [l.get_label() for l in list]
ax1.legend(list, labels, loc='upper left')

# %% [markdown]
# **Challenge**: Add colours to style the chart. This will help differentiate the two lines and the axis labels. Try using one of the blue [colour names](https://matplotlib.org/3.1.1/gallery/color/named_colors.html) for the search volume and a HEX code for a red colour for the stock price.
# <br>
# <br>
# Hint: you can colour both the [axis labels](https://matplotlib.org/3.3.2/api/text_api.html#matplotlib.text.Text) and the [lines](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) on the chart using keyword arguments (kwargs).

# %% [markdown]
# **Challenge**: Make the chart larger and easier to read.
# 1. Increase the figure size (e.g., to 14 by 8).
# 2. Increase the font sizes for the labels and the ticks on the x-axis to 14.
# 3. Rotate the text on the x-axis by 45 degrees.
# 4. Make the lines on the chart thicker.
# 5. Add a title that reads 'Tesla Web Search vs Price'
# 6. Keep the chart looking sharp by changing the dots-per-inch or [DPI value](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html).
# 7. Set minimum and maximum values for the y and x axis. Hint: check out methods like [set_xlim()](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_xlim.html).
# 8. Finally use [plt.show()](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.show.html) to display the chart below the cell instead of relying on the automatic notebook output.

# %%
df_tesla.head()
plt.figure(figsize=(14,8),dpi=80)
ax2 = plt.gca()
ax1 = plt.twinx()
l1, = ax1.plot(df_tesla.MONTH,df_tesla['TSLA_WEB_SEARCH'],label='Search Trend', color = 'blue',linewidth=3)
l2, = ax2.plot(df_tesla.MONTH,df_tesla.TSLA_USD_CLOSE,label='TSLA Stock Price', color = 'red',linewidth=3)
ax1.set_ylabel('Search Trend', color='blue', fontsize=14)
ax2.set_ylabel('TSLA Stock Price',color='red', fontsize=14)
plt.title('Tesla Web Search vs Price')
ax2.tick_params(axis = 'x', labelrotation=45)
ax1.set_ylim((0,600)) # you can use [] (list) as argument  too
ax1.set_xlim((df_tesla.MONTH.min(), df_tesla.MONTH.max())) # you can use [] (list) as argument too
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
list = [l1,l2]
labels = [l.get_label() for l in list]
ax1.legend(list, labels, loc='upper left')

# %% [markdown]
# How to add tick formatting for dates on the x-axis.

# %%
df_btc_search.sort_values(by='BTC_NEWS_SEARCH',ascending=False).head()
df_btc_price.head()
df_btc_monthly.head()
# Out:
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %% [markdown]
# ### Bitcoin (BTC) Price v.s. Search Volume

# %% [markdown]
# **Challenge**: Create the same chart for the Bitcoin Prices vs. Search volumes. <br>
# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price' <br>
# 2. Change the y-axis label to 'BTC Price' <br>
# 3. Change the y- and x-axis limits to improve the appearance <br>
# 4. Investigate the [linestyles](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html ) to make the BTC price a dashed line <br>
# 5. Investigate the [marker types](https://matplotlib.org/3.2.1/api/markers_api.html) to make the search datapoints little circles <br>
# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
plt.figure(figsize=(14,8),dpi=80)
ax1 = plt.gca()
ax2 = plt.twinx()
volume, = ax1.plot(df_btc_monthly.index, df_btc_monthly.VOLUME, color = 'b', linewidth= 3)
price, = ax2.plot(df_btc_price.CLOSE, color = 'red',linewidth =3)
ax1.set_ylabel('BTC Volume', color='blue', fontsize=14)
ax2.set_ylabel('BTC Price ',color='red', fontsize=14)
plt.title('Bitcoin News Search vs Resampled Price')
ax2.tick_params(axis = 'x', labelrotation=45)
ax1.set_ylim((0,1500)) # you can use [] (list) as argument  too
ax1.set_xlim((df_btc_monthly.index.min(), df_btc_monthly.max())) # you can use [] (list) as argument too
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)
list = [volume,price]
labels = [l.get_label() for l in list]
ax1.legend(list, labels, loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_60128\3588902626.py in ?()
#       7 ax2.set_ylabel('BTC Price ',color='red', fontsize=14)
#       8 plt.title('Bitcoin News Search vs Resampled Price')
#       9 ax2.tick_params(axis = 'x', labelrotation=45)
#      10 ax1.set_ylim((0,1500)) # you can use [] (list) as argument  too
# ---> 11 ax1.set_xlim((df_btc_monthly.index.min(), df_btc_monthly.max())) # you can use [] (list) as argument too
#      12 years = mdates.YearLocator()
#      13 months = mdates.MonthLocator()
#      14 years_fmt = mdates.DateFormatter('%Y')
#
# ~\PycharmProjects\100 Days of Code - Bootcamp\.venv\Lib\site-packages\matplotlib\axes\_base.py in ?(self, left, right, emit, auto, xmin, xmax)
#    3824         if xmax is not None:
#    3825             if right is not None:
#    3826                 raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3827             right = xmax
# -> 3828         return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# ~\PycharmProjects\100 Days of Code - Bootcamp\.venv\Lib\site-packages\matplotlib\axis.py in ?(self, v0, v1, emit, auto)
#    1236             if v1 <= 0:
#    1237                 _api.warn_external(f"Attempt to set non-positive {name}lim on "
#    1238                                    f"a log-scaled axis will be ignored.")
#    1239                 v1 = old1
# -> 1240         if v0 == v1:
#    1241             _api.warn_external(
#    1242                 f"Attempting to set identical low and high {name}lims "
#    1243                 f"makes transformation singular; automatically expanding.")
#
# ~\PycharmProjects\100 Days of Code - Bootcamp\.venv\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1511     @final
#    1512     def __bool__(self) -> NoReturn:
# -> 1513         raise ValueError(
#    1514             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1515             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1516         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Out:
#         DATE       CLOSE      VOLUME
# 0 2014-09-17  457.334015  21056800.0
# 1 2014-09-18  424.440002  34483200.0
# 2 2014-09-19  394.795990  37919700.0
# 3 2014-09-20  408.903992  36863600.0
# 4 2014-09-21  398.821014  26580100.0

# %% [markdown]
# ### Unemployement Benefits Search vs. Actual Unemployment in the U.S.

# %% [markdown]
# **Challenge** Plot the search for "unemployment benefits" against the unemployment rate.
# 1. Change the title to: Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate <br>
# 2. Change the y-axis label to: FRED U/E Rate <br>
# 3. Change the axis limits <br>
# 4. Add a grey [grid](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html) to the chart to better see the years and the U/E rate values. Use dashes for the line style<br>
# 5. Can you discern any seasonality in the searches? Is there a pattern?

# %% [markdown]
# **Challenge**: Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see in the chart? Which line moves first?

# %% [markdown]
# ### Including 2020 in Unemployment Charts

# %% [markdown]
# **Challenge**: Read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. Convert the MONTH column to Pandas Datetime objects and then plot the chart. What do you see?
