# %% [markdown]
# # Introduction
#
# Do higher film budgets lead to more box office revenue? Let's find out if there's a relationship using the movie budgets and financial performance data that I've scraped from [the-numbers.com](https://www.the-numbers.com/movie/budgets) on **May 1st, 2018**.
#
# <img src=https://i.imgur.com/kq7hrEh.png>
# <img src="./img_1.png">

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# # Read the Data

# %%
data = pd.read_csv('cost_revenue_dirty.csv')

# %% [markdown]
# # Explore and Clean the Data

# %% [markdown]
# **Challenge**: Answer these questions about the dataset:
# 1. How many rows and columns does the dataset contain?
# 2. Are there any NaN values present?
# 3. Are there any duplicate rows?
# 4. What are the data types of the columns?

# %%
print(f'There are => rows: {data.shape[0]}, columns: {data.shape[1]}')
# Out:
# There are => rows: 5391, columns: 6

# %%
print('Are there any Nan,None values?')
data.isna().any()
data.isna().values.any()
# Out:
# Are there any Nan,None values?
# np.False_

# %%
print('Are there any duplicates?')
data.duplicated().any()
data.duplicated().values.any()
# Out:
# Are there any duplicates?
# np.False_

# %%
data.columns
# Out:
# Index(['Rank', 'Release_Date', 'Movie_Title', 'USD_Production_Budget',
#        'USD_Worldwide_Gross', 'USD_Domestic_Gross'],
#       dtype='str')

# %% [markdown]
# ### Data Type Conversions

# %% [markdown]
# **Challenge**: Convert the `USD_Production_Budget`, `USD_Worldwide_Gross`, and `USD_Domestic_Gross` columns to a numeric format by removing `$` signs and `,`.
# <br>
# <br>
# Note that *domestic* in this context refers to the United States.

# %%
data.head()
# Out:
#    Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 0  5293     8/2/1915           The Birth of a Nation              $110,000
# 1  5140     5/9/1916                     Intolerance              $385,907
# 2  5230   12/24/1916    20,000 Leagues Under the Sea              $200,000
# 3  5299    9/17/1920  Over the Hill to the Poorhouse              $100,000
# 4  5222     1/1/1925                  The Big Parade              $245,000
#
#   USD_Worldwide_Gross USD_Domestic_Gross
# 0         $11,000,000        $10,000,000
# 1                  $0                 $0
# 2          $8,000,000         $8,000,000
# 3          $3,000,000         $3,000,000
# 4         $22,000,000        $11,000,000

# %%
chars_to_remove = [',', '$']
columns_to_clean = ['USD_Production_Budget',
                    'USD_Worldwide_Gross',
                    'USD_Domestic_Gross']

for col in columns_to_clean:
    for char in chars_to_remove:
        # Replace each character with an empty string
        data[col] = data[col].astype(str).str.replace(char, "")
    # Convert column to a numeric data type
    data[col] = pd.to_numeric(data[col])
data.head()
# Out:
#    Rank Release_Date                     Movie_Title  USD_Production_Budget  \
# 0  5293     8/2/1915           The Birth of a Nation                 110000
# 1  5140     5/9/1916                     Intolerance                 385907
# 2  5230   12/24/1916    20,000 Leagues Under the Sea                 200000
# 3  5299    9/17/1920  Over the Hill to the Poorhouse                 100000
# 4  5222     1/1/1925                  The Big Parade                 245000
#
#    USD_Worldwide_Gross  USD_Domestic_Gross
# 0             11000000            10000000
# 1                    0                   0
# 2              8000000             8000000
# 3              3000000             3000000
# 4             22000000            11000000

# %%
import numpy as np
import numbers as nu
d = dict([('$',''),(',','')])
if isinstance(data.USD_Production_Budget.dtype, str):
    data.USD_Production_Budget = pd.to_numeric(data.USD_Production_Budget.str.replace(d,None))
if  isinstance(data.USD_Worldwide_Gross.dtype, str):
    data.USD_Worldwide_Gross = pd.to_numeric(data.USD_Worldwide_Gross.str.replace(d,None))
if  isinstance(data.USD_Domestic_Gross.dtype, str):
    data.USD_Domestic_Gross = pd.to_numeric(data.USD_Domestic_Gross.str.replace(d,None))
data.dtypes
data.head()
data.USD_Domestic_Gross.dtype
# Out:
# dtype('int64')

# %%
usd_prod = data.USD_Production_Budget

# d = {'$': '',',': ''}
# usd_prod_conv = usd_prod.str.replace(d,None)
# usd_prod_conv = pd.to_numeric(usd_prod_conv)
# usd_prod_conv

# %% [markdown]
# **Challenge**: Convert the `Release_Date` column to a Pandas Datetime type.

# %%
data.head()
# Out:
#    Rank Release_Date                     Movie_Title  USD_Production_Budget  \
# 0  5293     8/2/1915           The Birth of a Nation                 110000
# 1  5140     5/9/1916                     Intolerance                 385907
# 2  5230   12/24/1916    20,000 Leagues Under the Sea                 200000
# 3  5299    9/17/1920  Over the Hill to the Poorhouse                 100000
# 4  5222     1/1/1925                  The Big Parade                 245000
#
#    USD_Worldwide_Gross  USD_Domestic_Gross
# 0             11000000            10000000
# 1                    0                   0
# 2              8000000             8000000
# 3              3000000             3000000
# 4             22000000            11000000

# %%
data.Release_Date = pd.to_datetime(data.Release_Date)
data.dtypes
# Out:
# Rank                              int64
# Release_Date             datetime64[us]
# Movie_Title                         str
# USD_Production_Budget             int64
# USD_Worldwide_Gross               int64
# USD_Domestic_Gross                int64
# dtype: object

# %%
import random
data.shape
data.head()
data.tail()
data.info() #this is gold
data.sample()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5391 entries, 0 to 5390
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   5391 non-null   int64
#  1   Release_Date           5391 non-null   datetime64[us]
#  2   Movie_Title            5391 non-null   str
#  3   USD_Production_Budget  5391 non-null   int64
#  4   USD_Worldwide_Gross    5391 non-null   int64
#  5   USD_Domestic_Gross     5391 non-null   int64
# dtypes: datetime64[us](1), int64(4), str(1)
# memory usage: 252.8 KB
#      Rank Release_Date                          Movie_Title  \
# 603  2198   1991-06-28  The Naked Gun 2½: The Smell of Fear
#
#      USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 603               23000000             86930411            86930411

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# **Challenge**:
#
# 1. What is the average production budget of the films in the data set?
# 2. What is the average worldwide gross revenue of films?
# 3. What were the minimums for worldwide and domestic revenue?
# 4. Are the bottom 25% of films actually profitable or do they lose money?
# 5. What are the highest production budget and highest worldwide gross revenue of any film?
# 6. How much revenue did the lowest and highest budget films make?

# %%
data.head()
data.dtypes
data.describe()
# Out:
#           Rank                Release_Date  USD_Production_Budget  \
# count 5,391.00                        5391               5,391.00
# mean  2,696.00  2003-09-19 15:02:02.203672          31,113,737.58
# min       1.00         1915-08-02 00:00:00               1,100.00
# 25%   1,348.50         1999-12-02 12:00:00           5,000,000.00
# 50%   2,696.00         2006-06-23 00:00:00          17,000,000.00
# 75%   4,043.50         2011-11-23 00:00:00          40,000,000.00
# max   5,391.00         2020-12-31 00:00:00         425,000,000.00
# std   1,556.39                         NaN          40,523,796.88
#
#        USD_Worldwide_Gross  USD_Domestic_Gross
# count             5,391.00            5,391.00
# mean         88,855,421.96       41,235,519.44
# min                   0.00                0.00
# 25%           3,865,206.00        1,330,901.50
# 50%          27,450,453.00       17,192,205.00
# 75%          96,454,455.00       52,343,687.00
# ...

# %%
data[['USD_Production_Budget','USD_Worldwide_Gross','USD_Domestic_Gross']].aggregate('mean')
print(f'average production budget: \n{data.aggregate({"USD_Production_Budget": ['mean']})}')
# Out:
# average production budget:
#       USD_Production_Budget
# mean          31,113,737.58

# %%
data.aggregate({"USD_Worldwide_Gross": 'mean'})
# Out:
# USD_Worldwide_Gross   88,855,421.96
# dtype: float64

# %%
data.agg({"USD_Domestic_Gross": 'min'})
# Out:
# USD_Domestic_Gross    0
# dtype: int64

# %%
data[data.USD_Production_Budget == 1100]
# Out:
#       Rank Release_Date        Movie_Title  USD_Production_Budget  \
# 2427  5391   2005-05-08  My Date With Drew                   1100
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 2427               181041              181041

# %%
data.describe()
# Out:
#           Rank                Release_Date  USD_Production_Budget  \
# count 5,391.00                        5391               5,391.00
# mean  2,696.00  2003-09-19 15:02:02.203672          31,113,737.58
# min       1.00         1915-08-02 00:00:00               1,100.00
# 25%   1,348.50         1999-12-02 12:00:00           5,000,000.00
# 50%   2,696.00         2006-06-23 00:00:00          17,000,000.00
# 75%   4,043.50         2011-11-23 00:00:00          40,000,000.00
# max   5,391.00         2020-12-31 00:00:00         425,000,000.00
# std   1,556.39                         NaN          40,523,796.88
#
#        USD_Worldwide_Gross  USD_Domestic_Gross
# count             5,391.00            5,391.00
# mean         88,855,421.96       41,235,519.44
# min                   0.00                0.00
# 25%           3,865,206.00        1,330,901.50
# 50%          27,450,453.00       17,192,205.00
# 75%          96,454,455.00       52,343,687.00
# ...

# %%
data[data.USD_Production_Budget == 425000000]
# Out:
#       Rank Release_Date Movie_Title  USD_Production_Budget  \
# 3529     1   2009-12-18      Avatar              425000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 3529           2783918982           760507625

# %%
zero_domestic = data[data.USD_Domestic_Gross == 0]
print(len(zero_domestic))
# Out:
# 512

# %%
zero_domestic.sort_values('USD_Production_Budget', ascending = False)
# Out:
#       Rank Release_Date                         Movie_Title  \
# 5388    96   2020-12-31                         Singularity
# 5387   126   2018-12-18                             Aquaman
# 5384   321   2018-09-03                   A Wrinkle in Time
# 5385   366   2018-10-08                      Amusement Park
# 5090   556   2015-12-31  Don Gato, el inicio de la pandilla
# ...    ...          ...                                 ...
# 4787  5371   2014-12-31                Stories of Our Lives
# 3056  5374   2007-12-31                         Tin Can Man
# 4907  5381   2015-05-19                    Family Motocross
# 5006  5389   2015-09-29             Signed Sealed Delivered
# 5007  5390   2015-09-29                A Plague So Pleasant
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5388              175000000                    0                   0
# 5387              160000000                    0                   0
# ...

# %%
data.describe()
# Out:
#           Rank                Release_Date  USD_Production_Budget  \
# count 5,391.00                        5391               5,391.00
# mean  2,696.00  2003-09-19 15:02:02.203672          31,113,737.58
# min       1.00         1915-08-02 00:00:00               1,100.00
# 25%   1,348.50         1999-12-02 12:00:00           5,000,000.00
# 50%   2,696.00         2006-06-23 00:00:00          17,000,000.00
# 75%   4,043.50         2011-11-23 00:00:00          40,000,000.00
# max   5,391.00         2020-12-31 00:00:00         425,000,000.00
# std   1,556.39                         NaN          40,523,796.88
#
#        USD_Worldwide_Gross  USD_Domestic_Gross
# count             5,391.00            5,391.00
# mean         88,855,421.96       41,235,519.44
# min                   0.00                0.00
# 25%           3,865,206.00        1,330,901.50
# 50%          27,450,453.00       17,192,205.00
# 75%          96,454,455.00       52,343,687.00
# ...

# %%
data[data.USD_Worldwide_Gross == 0]
# Out:
#       Rank Release_Date                       Movie_Title  \
# 1     5140   1916-05-09                       Intolerance
# 6     4630   1927-12-08                             Wings
# 8     4240   1930-01-01                     Hell's Angels
# 17    4814   1936-10-20  Charge of the Light Brigade, The
# 27    4789   1941-10-28           How Green Was My Valley
# ...    ...          ...                               ...
# 5386  2950   2018-10-08                               Meg
# 5387   126   2018-12-18                           Aquaman
# 5388    96   2020-12-31                       Singularity
# 5389  1119   2020-12-31            Hannibal the Conqueror
# 5390  2517   2020-12-31    Story of Bonnie and Clyde, The
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 1                    385907                    0                   0
# 6                   2000000                    0                   0
# ...

# %%
zero_worldwide = data[data.USD_Worldwide_Gross == 0]
zero_worldwide.sort_values(by ='USD_Production_Budget', ascending = False)
# 175 000 000
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 5388    96   2020-12-31              Singularity              175000000
# 5387   126   2018-12-18                  Aquaman              160000000
# 5384   321   2018-09-03        A Wrinkle in Time              103000000
# 5385   366   2018-10-08           Amusement Park              100000000
# 5058   880   2015-11-12         The Ridiculous 6               60000000
# ...    ...          ...                      ...                    ...
# 4787  5371   2014-12-31     Stories of Our Lives                  15000
# 3056  5374   2007-12-31              Tin Can Man                  12000
# 4907  5381   2015-05-19         Family Motocross                  10000
# 5006  5389   2015-09-29  Signed Sealed Delivered                   5000
# 5007  5390   2015-09-29     A Plague So Pleasant                   1400
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 5388                    0                   0
# ...

# %% [markdown]
# # Investigating the Zero Revenue Films

# %% [markdown]
# ### Filtering on Multiple Conditions

# %%
# data[(data.USD_Worldwide_Gross != 0) & (data.USD_Domestic_Gross == 0)] this works too
bitwise_and = data.loc[(data.USD_Worldwide_Gross != 0) & (data.USD_Domestic_Gross == 0)]
#and doesn't work here, you have to use &
bitwise_and
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
# ...    ...          ...                      ...                    ...
# 5340  1506   2017-04-14      Queen of the Desert               36000000
# 5348  2225   2017-05-05        Chāi dàn zhuānjiā               23000000
# 5360  4832   2017-07-03                Departure                1100000
# 5372  1856   2017-08-25                Ballerina               30000000
# 5374  4237   2017-08-25     Polina danser sa vie                4000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# ...

# %%
#and here we have alternative reality of pandas xD
data.query('USD_Domestic_Gross == 0 and USD_Worldwide_Gross != 0')
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
# ...    ...          ...                      ...                    ...
# 5340  1506   2017-04-14      Queen of the Desert               36000000
# 5348  2225   2017-05-05        Chāi dàn zhuānjiā               23000000
# 5360  4832   2017-07-03                Departure                1100000
# 5372  1856   2017-08-25                Ballerina               30000000
# 5374  4237   2017-08-25     Polina danser sa vie                4000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# ...

# %%
data.loc[(data.Movie_Title == 'Aquaman')]
data.query("Release_Date >= '2018-05-1' and USD_Worldwide_Gross == 0 and USD_Domestic_Gross == 0")
# Out:
#       Rank Release_Date                     Movie_Title  \
# 5384   321   2018-09-03               A Wrinkle in Time
# 5385   366   2018-10-08                  Amusement Park
# 5386  2950   2018-10-08                             Meg
# 5387   126   2018-12-18                         Aquaman
# 5388    96   2020-12-31                     Singularity
# 5389  1119   2020-12-31          Hannibal the Conqueror
# 5390  2517   2020-12-31  Story of Bonnie and Clyde, The
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5384              103000000                    0                   0
# 5385              100000000                    0                   0
# 5386               15000000                    0                   0
# 5387              160000000                    0                   0
# 5388              175000000                    0                   0
# 5389               50000000                    0                   0
# ...

# %%
print(f'how many: {data.query("Release_Date >= '2018-05-1' and USD_Worldwide_Gross == 0 and USD_Domestic_Gross == 0").shape[0]}')
# Out:
# how many: 7

# %%
data_clean = data.query('Release_Date < "2018-05-01"')
#or
stamp = pd.Timestamp("2018-05-01")
data_clean_ = data.loc[data.Release_Date >= stamp]
# data_clean.loc[(data.Movie_Title == 'Aquaman')]
# data_clean.loc[(data.Movie_Title == 'Singularity')]
#data_clean.shape => yep, it is clear xD
data_clean_
data_clean
# Out:
#       Rank Release_Date                       Movie_Title  \
# 0     5293   1915-08-02             The Birth of a Nation
# 1     5140   1916-05-09                       Intolerance
# 2     5230   1916-12-24      20,000 Leagues Under the Sea
# 3     5299   1920-09-17    Over the Hill to the Poorhouse
# 4     5222   1925-01-01                    The Big Parade
# ...    ...          ...                               ...
# 5379  1295   2017-10-02            John Wick: Chapter Two
# 5380    70   2017-10-03                Kong: Skull Island
# 5381    94   2017-12-05  King Arthur: Legend of the Sword
# 5382  1254   2017-12-05                          Snatched
# 5383  2521   2017-12-31                The Thousand Miles
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 0                    110000             11000000            10000000
# 1                    385907                    0                   0
# ...

# %% [markdown]
# **Challenge**: Use the [`.query()` function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) to accomplish the same thing. Create a subset for international releases that had some worldwide gross revenue, but made zero revenue in the United States.
#
# Hint: This time you'll have to use the `and` keyword.

# %%
data.head()
data.query('USD_Worldwide_Gross > 0 and USD_Domestic_Gross == 0')
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
# ...    ...          ...                      ...                    ...
# 5340  1506   2017-04-14      Queen of the Desert               36000000
# 5348  2225   2017-05-05        Chāi dàn zhuānjiā               23000000
# 5360  4832   2017-07-03                Departure                1100000
# 5372  1856   2017-08-25                Ballerina               30000000
# 5374  4237   2017-08-25     Polina danser sa vie                4000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# ...

# %% [markdown]
# ### Unreleased Films
#
# **Challenge**:
# * Identify which films were not released yet as of the time of data collection (May 1st, 2018).
# * How many films are included in the dataset that have not yet had a chance to be screened in the box office?
# * Create another DataFrame called data_clean that does not include these films.

# %%
# Date of Data Collection
scrape_date = pd.Timestamp('2018-5-1')

# %%
future_releases = data.loc[data.Release_Date >= scrape_date]
future_releases
# Out:
#       Rank Release_Date                     Movie_Title  \
# 5384   321   2018-09-03               A Wrinkle in Time
# 5385   366   2018-10-08                  Amusement Park
# 5386  2950   2018-10-08                             Meg
# 5387   126   2018-12-18                         Aquaman
# 5388    96   2020-12-31                     Singularity
# 5389  1119   2020-12-31          Hannibal the Conqueror
# 5390  2517   2020-12-31  Story of Bonnie and Clyde, The
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5384              103000000                    0                   0
# 5385              100000000                    0                   0
# 5386               15000000                    0                   0
# 5387              160000000                    0                   0
# 5388              175000000                    0                   0
# 5389               50000000                    0                   0
# ...

# %%
clean_data = data.drop(future_releases.index)
clean_data
# Out:
#       Rank Release_Date                       Movie_Title  \
# 0     5293   1915-08-02             The Birth of a Nation
# 1     5140   1916-05-09                       Intolerance
# 2     5230   1916-12-24      20,000 Leagues Under the Sea
# 3     5299   1920-09-17    Over the Hill to the Poorhouse
# 4     5222   1925-01-01                    The Big Parade
# ...    ...          ...                               ...
# 5379  1295   2017-10-02            John Wick: Chapter Two
# 5380    70   2017-10-03                Kong: Skull Island
# 5381    94   2017-12-05  King Arthur: Legend of the Sword
# 5382  1254   2017-12-05                          Snatched
# 5383  2521   2017-12-31                The Thousand Miles
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 0                    110000             11000000            10000000
# 1                    385907                    0                   0
# ...

# %% [markdown]
# ### Films that Lost Money
#
# **Challenge**:
# What is the percentage of films where the production costs exceeded the worldwide gross revenue?

# %%
clean_data.describe()
# Out:
#           Rank                Release_Date  USD_Production_Budget  \
# count 5,384.00                        5384               5,384.00
# mean  2,698.11  2003-09-12 00:26:12.659732          31,038,476.84
# min       1.00         1915-08-02 00:00:00               1,100.00
# 25%   1,351.75         1999-12-02 00:00:00           5,000,000.00
# 50%   2,698.50         2006-06-16 00:00:00          17,000,000.00
# 75%   4,045.25         2011-11-18 00:00:00          40,000,000.00
# max   5,391.00         2017-12-31 00:00:00         425,000,000.00
# std   1,555.79                         NaN          40,440,041.47
#
#        USD_Worldwide_Gross  USD_Domestic_Gross
# count             5,384.00            5,384.00
# mean         88,970,947.21       41,289,131.75
# min                   0.00                0.00
# 25%           3,929,036.00        1,354,765.25
# 50%          27,537,329.00       17,221,932.00
# 75%          96,641,996.25       52,403,530.00
# ...

# %%
percent = ((clean_data.query('USD_Production_Budget > USD_Worldwide_Gross').shape[0] / clean_data.shape[0]) * 100)
percent.__round__(2)
# Out:
# 37.28

# %% [markdown]
# # Seaborn for Data Viz: Bubble Charts

# %%
import seaborn as sns
df = sns.load_dataset("penguins")
sns.pairplot(df, hue = "species")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(data = data_clean,
                x = 'USD_Production_Budget',
                y = 'USD_Worldwide_Gross')
# Out:
# <Axes: xlabel='USD_Production_Budget', ylabel='USD_Worldwide_Gross'>

# %%
plt.figure(figsize=(8,4), dpi = 200)
sns.scatterplot(data = data_clean,
                x = 'USD_Production_Budget',
                y = 'USD_Worldwide_Gross')
plt.show()

# %%
# type(sns.scatterplot())
plt.figure(figsize=(8,4), dpi=200)

ax = sns.scatterplot(data=data_clean,
                     x='USD_Production_Budget',
                     y='USD_Worldwide_Gross')
ax.set(ylim=(0, 3000000000),
       xlim=(0, 450000000),
       ylabel='Revenue in $ billions',
       xlabel='Budget in $100 millions',)

plt.show()

# %% [markdown]
# ### Plotting Movie Releases over Time
#
# **Challenge**: Try to create the following Bubble Chart:
#
# <img src=https://i.imgur.com/8fUn9T6.png>
# <img src="./imgur_1.png">

# %%
plt.figure(figsize=(8,4), dpi=200)
ax = sns.scatterplot(data=data_clean,
                     x='USD_Production_Budget',
                     y='USD_Worldwide_Gross',
                     hue='USD_Worldwide_Gross', # colour
                     size='USD_Worldwide_Gross',) # dot size

ax.set(ylim=(0, 3000000000),
       xlim=(0, 450000000),
       ylabel='Revenue in $ billions',
       xlabel='Budget in $100 millions',)

plt.show()

# %%
plt.figure(figsize=(8,4), dpi=200)

# set styling on a single chart
with sns.axes_style('darkgrid'): # whitegrid, dark, ticks, darkgrid
  ax = sns.scatterplot(data=data_clean,
                       x='USD_Production_Budget',
                       y='USD_Worldwide_Gross',
                       hue='USD_Worldwide_Gross',
                       size='USD_Worldwide_Gross')

  ax.set(ylim=(0, 3000000000),
        xlim=(0, 450000000),
        ylabel='Revenue in $ billions',
        xlabel='Budget in $100 millions')

# %%
plt.figure(figsize=(8,4), dpi=200)

with sns.axes_style("darkgrid"):
    ax = sns.scatterplot(data=data_clean,
                    x='Release_Date',
                    y='USD_Production_Budget',
                    hue='USD_Worldwide_Gross',
                    size='USD_Worldwide_Gross',)

    ax.set(ylim=(0, 450000000),
           xlim=(data_clean.Release_Date.min(), data_clean.Release_Date.max()),
           xlabel='Year',
           ylabel='Budget in $100 millions')

# %% [markdown]
# # Converting Years to Decades Trick
#
# **Challenge**: Create a column in `data_clean` that has the decade of the release.
#
# <img src=https://i.imgur.com/0VEfagw.png width=650>
# <img src="./imgur_2.png" width=650>
# Here's how:
# 1. Create a [`DatetimeIndex` object](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DatetimeIndex.html) from the Release_Date column.
# 2. Grab all the years from the `DatetimeIndex` object using the `.year` property.
# <img src=https://i.imgur.com/5m06Ach.png width=650>
# 3. Use floor division `//` to convert the year data to the decades of the films.
# 4. Add the decades as a `Decade` column to the `data_clean` DataFrame.

# %%
data_source = clean_data.Release_Date
decades = pd.DatetimeIndex(data_source)
decades.year
clean_decades = (decades.year // 10)*10
clean_decades
data_clean['Decade'] = clean_decades # creating new column called Decade
data_clean
# Out:
#       Rank Release_Date                       Movie_Title  \
# 0     5293   1915-08-02             The Birth of a Nation
# 1     5140   1916-05-09                       Intolerance
# 2     5230   1916-12-24      20,000 Leagues Under the Sea
# 3     5299   1920-09-17    Over the Hill to the Poorhouse
# 4     5222   1925-01-01                    The Big Parade
# ...    ...          ...                               ...
# 5379  1295   2017-10-02            John Wick: Chapter Two
# 5380    70   2017-10-03                Kong: Skull Island
# 5381    94   2017-12-05  King Arthur: Legend of the Sword
# 5382  1254   2017-12-05                          Snatched
# 5383  2521   2017-12-31                The Thousand Miles
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 0                    110000             11000000            10000000    1910
# 1                    385907                    0                   0    1910
# ...

# %%
data_clean.Decade.dtype
old_films_1 = data_clean.where(data_clean.Decade <= 1960).dropna() # where() doesn't filter by removing but replacing rows NaN values
new_films_1 = data_clean.where(data_clean.Decade > 1960).dropna()
# 1960, because before was (date//10)*10 and 1970 equal 1970-1980 xD
old_films_2 = data_clean.where(data_clean.Release_Date > pd.to_datetime('1970-01-01')).dropna()
new_films_2 = data_clean.where(data_clean.Release_Date < pd.to_datetime('1970-01-01')).dropna()
old_films = data_clean[data_clean.Decade <= 1960] # proper way
old_films_ = data_clean.query('Decade <= 1960')  # alternative proper way
new_films = data_clean[data_clean.Release_Date > pd.to_datetime('1970-01-01')] # proper way
new_films_ = data_clean.query('Release_Date > @pd.to_datetime("1970-01-01")') # alternative proper way
# => `@` use it, always you need to tell query string you use function | variable
print(f'new films count: {new_films.shape[0]}, old films count: {old_films.shape[0]} the most expensive films released before 1970\'s: {old_films.USD_Production_Budget.max()}')
# Out:
# new films count: 5225, old films count: 153 the most expensive films released before 1970's: 42000000

# %%
old_films.describe()
old_films.sort_values('USD_Production_Budget', ascending=False).head(n=10)
# Out:
#      Rank Release_Date                   Movie_Title  USD_Production_Budget  \
# 109  1253   1963-12-06                     Cleopatra               42000000
# 150  2175   1969-12-16                  Hello, Dolly               24000000
# 118  2425   1965-02-15  The Greatest Story Ever Told               20000000
# 143  2465   1969-01-01                 Sweet Charity               20000000
# 148  2375   1969-10-15              Paint Your Wagon               20000000
# 98   2546   1962-08-11          Mutiny on The Bounty               19000000
# 110  2552   1964-01-01  The Fall of the Roman Empire               19000000
# 114  2670   1964-10-22                  My Fair Lady               17000000
# 102  2698   1963-01-01             55 Days at Peking               17000000
# 100  2827   1962-12-16            Lawrence of Arabia               15000000
#
#      USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 109             71000000            57000000    1960
# ...

# %%
plt.figure(figsize=(8,4))

ax = sns.scatterplot()

ax.set()

plt.show()

# %% [markdown]
# # Seaborn Regression Plots

# %%
sns.regplot(data=old_films,
            x='USD_Production_Budget',
            y='USD_Worldwide_Gross')
# Out:
# <Axes: xlabel='USD_Production_Budget', ylabel='USD_Worldwide_Gross'>

# %%
plt.figure(figsize=(8,4), dpi=200)
with sns.axes_style('darkgrid'):
  sns.regplot(data=old_films,
              x='USD_Production_Budget',
              y='USD_Worldwide_Gross',
              scatter_kws = {'alpha': 0.4},
              line_kws = {'color': 'black'})
  plt.show()

# %% [markdown]
# **Challenge**: Use Seaborn's `.regplot()` to show the scatter plot and linear regression line against the `new_films`.
# <br>
# <br>
# Style the chart
#
# * Put the chart on a `'darkgrid'`.
# * Set limits on the axes so that they don't show negative values.
# * Label the axes on the plot "Revenue in \$ billions" and "Budget in \$ millions".
# * Provide HEX colour codes for the plot and the regression line. Make the dots dark blue (#2f4b7c) and the line orange (#ff7c43).
#
# Interpret the chart
#
# * Do our data points for the new films align better or worse with the linear regression than for our older films?
# * Roughly how much would a film with a budget of $150 million make according to the regression line?

# %%
plt.figure(figsize=(8,4), dpi=200)
with sns.axes_style('darkgrid'):
  ax = sns.regplot(data=new_films,
              x='USD_Production_Budget',
              y='USD_Worldwide_Gross',
              color='#2f4b7c',
              line_kws={'color': '#ff7c43'},
              scatter_kws={'alpha': 0.3},
                   )
  ax.set(
    ylim = (new_films.USD_Worldwide_Gross.min(), new_films.USD_Worldwide_Gross.max()),
    xlim = (new_films.USD_Production_Budget.min(), new_films.USD_Production_Budget.max()),
    ylabel = ('Revenue in $ billions.'),
    xlabel = ('Budget in $ 100 millions.'),
  )
  plt.show()

# %%
print(f'max: {new_films.USD_Production_Budget.max():_.0f}'
      f' min: {new_films.USD_Production_Budget.min()}')
print(f'max: {new_films.USD_Worldwide_Gross.max():_.0f}'
      f' min: {new_films.USD_Worldwide_Gross.min()}')

# %% [markdown]
# # Run Your Own Regression with scikit-learn
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
# Explanatory Variable(s) or Feature(s)
X = pd.DataFrame(new_films, columns=['USD_Production_Budget'])
# Response Variable or Target
y = pd.DataFrame(new_films, columns=['USD_Worldwide_Gross'])
# We're creating new pandas dataframes, based on single columns from new_films dataframe
# find the best-fit line

regression.fit(X, y)
# Out:
# LinearRegression()

# %%
# Theta zero (-8,5 millions $)
regression.intercept_
# Out:
# array([-8653668.6979281])

# %%
# Theta one (+3,12 $)
regression.coef_
# Out:
# array([[3.12280986]])

# %%
regression.score(X, y)
# Out:
# 0.5577186673054811

# %% [markdown]
# **Challenge**: Run a linear regression for the `old_films`. Calculate the intercept, slope and r-squared. How much of the variance in movie revenue does the linear model explain in this case?

# %%
regression = LinearRegression()
X = pd.DataFrame(old_films, columns=['USD_Production_Budget'])
y = pd.DataFrame(old_films, columns=['USD_Worldwide_Gross'])
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
# Theta zero
regression.intercept_
# Out:
# array([22821538.63508039])

# %%
# Theta one
regression.coef_
# Out:
# array([[1.64771314]])

# %%
# R-squared
regression.score(X,y)
# Out:
# 0.02937258620576877

# %% [markdown]
# # Use Your Model to Make a Prediction
#
# We just estimated the slope and intercept! Remember that our Linear Model has the following form:
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$
#
# **Challenge**:  How much global revenue does our model estimate for a film with a budget of $350 million?

# %%
# revenue is equal theta0 plus theta1*Budget, based on this equasion you
# can predict probably revenue, but with only 3% (old_films) probability
# and 56% (new_films) probability
type(regression.intercept_.item())
regression.coef_.item()
budget = 350000000
revenue = regression.intercept_[0].item() + regression.coef_[0,0].item() * budget
revenue
# Out:
# 599521139.0388364

# %% [markdown]
# Learning Points & Summary
# Today was a pretty packed lesson where we introduced a lot of new concepts. In this lesson we looked at how to:
#
# Use nested loops to remove unwanted characters from multiple columns
#
# Filter Pandas DataFrames based on multiple conditions using both .loc[] and .query()
#
# Create bubble charts using the Seaborn Library
#
# Style Seaborn charts using the pre-built styles and by modifying Matplotlib parameters
#
# Use floor division (i.e., integer division) to convert years to decades
#
# Use Seaborn to superimpose a linear regressions over our data
#
# Make a judgement if our regression is good or bad based on how well the model fits our data and the r-squared metric
#
# Run regressions with scikit-learn and calculate the coefficients.
